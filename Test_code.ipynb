# %%
# Out:
# Mounted at /content/drive
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-12f9c71dcf47> in <cell line: 0>()
#       2 drive.mount('/content/drive')
#       3
# ----> 4 cd /content/drive/MyDrive/Commit_Test_Folder
#       5
#       6 get_ipython().system('git clone https://PARKHAJIN1001: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@github.com/PARKHAJIN1001/Test_CenterNet.git')
#
# NameError: name 'cd' is not defined

# %%
# !git add Test_code.ipynb
